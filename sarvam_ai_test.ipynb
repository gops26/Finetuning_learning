# %% [markdown]
# ## Sarvam AI Experimentation
#
# - Sarvam A.I. is India's first large language model. I just came across it on my LinkedIn. I want to try this LLM, this is an LLM experimentation for Sarvam A.I.
# - This Jupyter Notebook is my experimentation of Sarvam, a large language model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
! pip install sarvamai

# %%
from sarvamai import SarvamAI
from dotenv import load_dotenv
import os

load_dotenv()
client = SarvamAI(
    api_subscription_key = os.environ["SARVAM"]
)
